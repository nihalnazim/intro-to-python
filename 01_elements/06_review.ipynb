# %% [markdown]
# # Chapter 1: Elements of a Program (Review Questions)

# %% [markdown]
# The questions below assume that you have read the [first <img height="12" style="display: inline-block" src="../static/link/to_nb.png">](https://nbviewer.jupyter.org/github/webartifex/intro-to-python/blob/main/01_elements/00_content.ipynb) and the [second <img height="12" style="display: inline-block" src="../static/link/to_nb.png">](https://nbviewer.jupyter.org/github/webartifex/intro-to-python/blob/main/01_elements/03_content.ipynb) part of Chapter 1.
#
# Be concise in your answers! Most questions can be answered in *one* sentence.

# %% [markdown]
# ## Essay Questions

# %% [markdown]
# **Q1**: For what use case might **modulo division** be helpful?

# %% [markdown]
#  < your answer >

# %% [markdown]
# **Q2**: What is the benefit of following basic **naming conventions** for variables?

# %% [markdown]
#  < your answer >

# %% [markdown]
# ## True / False Questions

# %% [markdown]
# *Provide ~1 sentence of context for your answers.*

# %% [markdown]
# **Q3:** Python starts counting at 0, not 1.

# %% [markdown]
# < your answer >

# %% [markdown]
# **Q4**: The **Zen of Python** talks about genius programmers.

# %% [markdown]
#  < your answer >

# %% [markdown]
# **Q5**: When NASA famously converted some measurements to the wrong unit and lost a Mars satellite in 1999 (cf., [source](https://www.wired.com/2010/11/1110mars-climate-observer-report/)), this is an example of a so-called **runtime error**.

# %% [markdown]
#  < your answer >
